# %% [markdown]
# instalr e importar librerias

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python  PySerial

# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import cv2
import tkinter as tk

# %% [markdown]
# cargar el modelo

# %%
interpreter = tf.lite.Interpreter(model_path='lite-model_movenet_singlepose_lightning_3.tflite')
interpreter.allocate_tensors()

# %% [markdown]
# interfas grafica

# %%
app=tk.Tk()  #crear ventana principal
app.geometry("500x600") # dimencionar la ventana  "ancho x alto"
app.configure(background="gray")  # cambiar color de fondo
tk.Wm.wm_title(app, "LANZADOR DE PELOTAS") # colocar titulo a la ventana (ventana, "titulo")

tk.Label(app, text="ENTRENAMIENTO CON LANZADOR",font=("Verdana",20),bg="gray").pack()
tk.Label(app, text="DE PELOTAS",font=("Verdana",20),bg="gray").pack()
L1=tk.Label(app,text="SELECCIONAR PARTES DEL CUERPO A SEGUIR ",font=("Verdana",15),bg="gray").pack()
C1=tk.Checkbutton(app,text="CABEZA",bg="gray",font=("Verdana",12))
C1.place(x=30,y=110)
C2=tk.Checkbutton(app,text="HOMBROS",bg="gray",font=("Verdana",12))
C2.place(x=190,y=110)
C3=tk.Checkbutton(app,text="PECHO",bg="gray",font=("Verdana",12))
C3.place(x=350,y=110)
C4=tk.Checkbutton(app,text="CODOS",bg="gray",font=("Verdana",12))
C4.place(x=30,y=150)
C5=tk.Checkbutton(app,text="ABDOMEN",bg="gray",font=("Verdana",12))
C5.place(x=190,y=150)
C6=tk.Checkbutton(app,text="MANOS",bg="gray",font=("Verdana",12))
C6.place(x=350,y=150)
C7=tk.Checkbutton(app,text="CADERA",bg="gray",font=("Verdana",12))
C7.place(x=30,y=190)
C8=tk.Checkbutton(app,text="MUSLOS",bg="gray",font=("Verdana",12))
C8.place(x=190,y=190)
C9=tk.Checkbutton(app,text="RODILLAS",bg="gray",font=("Verdana",12))
C9.place(x=350,y=190)
C10=tk.Checkbutton(app,text="PANTORRILLAS",bg="gray",font=("Verdana",12))
C10.place(x=90,y=230)
C11=tk.Checkbutton(app,text="TOBILLOS",bg="gray",font=("Verdana",12))
C11.place(x=300,y=230)
L2=tk.Label(app,text="SELECCIONAR VELOCIDADES DE LANZAMIENTO",font=("Verdana",15),bg="gray")
L2.place(x=1,y=290)
C12=tk.Checkbutton(app,text="1 m/s",bg="gray",font=("Verdana",12))
C12.place(x=30,y=320)
C13=tk.Checkbutton(app,text="2 m/s",bg="gray",font=("Verdana",12))
C13.place(x=120,y=320)
C14=tk.Checkbutton(app,text="3 m/s",bg="gray",font=("Verdana",12))
C14.place(x=210,y=320)
C15=tk.Checkbutton(app,text="4 m/s",bg="gray",font=("Verdana",12))
C15.place(x=300,y=320)
C16=tk.Checkbutton(app,text="5 m/s",bg="gray",font=("Verdana",12))
C16.place(x=390,y=320)
C17=tk.Checkbutton(app,text="6 m/s",bg="gray",font=("Verdana",12))
C17.place(x=30,y=350)
C18=tk.Checkbutton(app,text="7 m/s",bg="gray",font=("Verdana",12))
C18.place(x=120,y=350)
C19=tk.Checkbutton(app,text="8 m/s",bg="gray",font=("Verdana",12))
C19.place(x=210,y=350)
C20=tk.Checkbutton(app,text="9 m/s",bg="gray",font=("Verdana",12))
C20.place(x=300,y=350)
C21=tk.Checkbutton(app,text="10 m/s",bg="gray",font=("Verdana",12))
C21.place(x=390,y=350)
L3=tk.Label(app,text="SELECCIONAR INTERVALOS DE LANZAMIENTO",font=("Verdana",15),bg="gray")
L3.place(x=1,y=410)
C22=tk.Checkbutton(app,text="1 s",bg="gray",font=("Verdana",12))
C22.place(x=30,y=440)
C23=tk.Checkbutton(app,text="2 s",bg="gray",font=("Verdana",12))
C23.place(x=120,y=440)
C24=tk.Checkbutton(app,text="3 s",bg="gray",font=("Verdana",12))
C24.place(x=210,y=440)
C25=tk.Checkbutton(app,text="4 s",bg="gray",font=("Verdana",12))
C25.place(x=300,y=440)
C26=tk.Checkbutton(app,text="5 s",bg="gray",font=("Verdana",12))
C26.place(x=390,y=440)
C27=tk.Checkbutton(app,text="6 s",bg="gray",font=("Verdana",12))
C27.place(x=30,y=470)
C28=tk.Checkbutton(app,text="7 s",bg="gray",font=("Verdana",12))
C28.place(x=120,y=470)
C29=tk.Checkbutton(app,text="8 s",bg="gray",font=("Verdana",12))
C29.place(x=210,y=470)
C30=tk.Checkbutton(app,text="9 s",bg="gray",font=("Verdana",12))
C30.place(x=300,y=470)
C31=tk.Checkbutton(app,text="10 s",bg="gray",font=("Verdana",12))
C31.place(x=390,y=470)
B1=tk.Button(app,text="INICIAR ENTRENAMIENTO ",font=("Verdana",15))
B1.place(x=100,y=540)
app.mainloop() #refresca la ventana

# %% [markdown]
# funcion para dibujar puntos

# %%
def draw_keypoints(frame, keypoints, confidence_threshold):
    y, x, c = frame.shape # extraer la forma del marco
    shaped = np.squeeze(np.multiply(keypoints, [y,x,1]))
    
    for kp in shaped:
        ky, kx, kp_conf = kp
        if kp_conf > confidence_threshold:
            cv2.circle(frame, (int(kx), int(ky)), 4, (0,255,0), -1)

# %%
def pasosH(pixel):
    distancia=pixel 
    global paso
    paso=b'?'
   
    if distancia <= 102: #12
        paso=b'!' 
    if distancia >=103  and distancia <=110:  #13
        paso=b'"' 
    if distancia >=111  and distancia <=117:   #14
        paso=b'#'
    if distancia >=118  and distancia <=124: #15
        paso=b'$'
    if distancia >=125  and distancia <=131:   #16
        paso=b'%'
    if distancia >=132  and distancia <=139:  #17
        paso=b'&'
    if distancia >=140  and distancia <=147: #18
        paso=b'('
    if distancia >=148  and distancia <=154: #19
        paso=b')'
    if distancia >=155  and distancia <= 162: #20
        paso=b'*'
    if distancia >=163  and distancia <= 170: #21
        paso=b'+'
    if distancia >=171  and distancia <=177: #22
        paso=b','
    if distancia >=178  and distancia <=185: #23
        paso=b'-'
    if distancia >=186  and distancia <=193: #24
        paso=b'.'
    if distancia >=194  and distancia <=201: #25
        paso=b'/'
    if distancia >=202  and distancia <=208:  #26
        paso=b'0'
    if distancia >=209  and distancia <=217: #27
        paso=b'1'
    if distancia >=218  and distancia <=224:  #28
        paso=b'2'
    if distancia >=225  and distancia <=232: #29
        paso=b'3'
    if distancia >=233  and distancia <=240: #30
        paso=b'4'
    if distancia >=241  and distancia <=249:  #31
        paso=b'5'
    if distancia >=250  and distancia <=256:  #32
        paso=b'6'
    if distancia >=257  and distancia <=264:  #33
        paso=b'7'
    if distancia >=265  and distancia <=272:  #34
        paso=b'8'
    if distancia >=273  and distancia <=280:  #35
        paso=b'9'
    if distancia >=281  and distancia <=288:  #36
        paso=b':'
    if distancia >=289  and distancia <=296:  #37
        paso=b';'
    if distancia >=397  and distancia <=304:  #38
        paso=b'<'
    if distancia >=305  and distancia <=312:  #39
        paso=b'='
    if distancia >=313  and distancia <=320:  #40
        paso=b'>'
    if distancia >=321  and distancia <=329:  #44  ///////
        paso=b'?'
    if distancia >=330  and distancia <=336:  #42
        paso=b'@'
    if distancia >=337  and distancia <=345:  #43
        paso=b'A'
    if distancia >=346  and distancia <=338:  #44
        paso=b'B'
    if distancia >=339  and distancia <=347:  #45
        paso=b'C'
    if distancia >=348  and distancia <=352:  #46
        paso=b'D'
    if distancia >=353  and distancia <=361:  #47
        paso=b'E'
    if distancia >=362  and distancia <=369:  #48
        paso=b'F'
    if distancia >=370  and distancia <=378: #49
        paso=b'G'
    if distancia >=379  and distancia <=385:  #50
        paso=b'H'
    if distancia >=386  and distancia <=394:  #51
        paso=b'I'
    if distancia >=395  and distancia <=402:  #52
        paso=b'J'
    if distancia >=403  and distancia <=410:  #53
        paso=b'K'
    if distancia >=411  and distancia <=418:  #54
        paso=b'L'
    if distancia >=419  and distancia <=426:  #55
        paso=b'M'
    if distancia >=427  and distancia <=433:  #56
        paso=b'N'
    if distancia >=434  and distancia <=442:  #57
        paso=b'O'
    if distancia >=443  and distancia <=450:  #58
        paso=b'P'
    if distancia >=451  and distancia <=458:  #59
        paso=b'Q'
    if distancia >=459  and distancia <=465:  #60
        paso=b'R'
    if distancia >=466  and distancia <=473:  #61
        paso=b'S'
    if distancia >=474  and distancia <=481:  #62
        paso=b'T'
    if distancia >=482  and distancia <=489:  #63
        paso=b'U'
    if distancia >=490  and distancia <=497:  #64
        paso=b'V'
    if distancia >=498  and distancia <=502:  #65
        paso=b'W'
    if distancia >=503  and distancia <=512:  #66
        paso=b'X'
    if distancia >=513  and distancia <=520:  #67
        paso=b'Y'
    if distancia >=521  and distancia <=527:  #68
        paso=b'Z'
    if distancia >=528  and distancia <=536:  #69
        paso=b'['
    if distancia >=537  and distancia <=543:  #70
        paso=b']'    
    if distancia >=550:   #71
        paso=b'^'
    
    return paso

# %%
def pasosV(pixel):
    distancia=pixel
    global pasoV
    pasoV=b'_'
   
    if distancia <= 84: #54
        pasoV=b'_' 
    if distancia >=85  and distancia <=92:  #55
        pasoV=b'`' 
    if distancia >=93  and distancia <=99:   #56
        pasoV=b'a'
    if distancia >=100  and distancia <=108: #57
        pasoV=b'b'
    if distancia >=109  and distancia <=114:   #58
        pasoV=b'c'
    if distancia >=115  and distancia <=123:  #59
        pasoV=b'd'
    if distancia >=124  and distancia <=130: #60
        pasoV=b'e'
    if distancia >=131  and distancia <= 138: #61
        pasoV=b'f'
    if distancia >=139  and distancia <= 145: #62
        pasoV=b'g'
    if distancia >=146  and distancia <= 154: #63
        pasoV=b'h'
    if distancia >=155  and distancia <= 161: #64
        pasoV=b'i'
    if distancia >=162  and distancia <=169: #65
        pasoV=b'j'
    if distancia >=170  and distancia <= 177: #66
        pasoV=b'k'
    if distancia >=178  and distancia <= 185: #67
        pasoV=b'l'
    if distancia >=186  and distancia <=193:  #68
        pasoV=b'm'
    if distancia >=194  and distancia <=201: #69
        pasoV=b'n'
    if distancia >=202  and distancia <=209:  #70
        pasoV=b'o'
    if distancia >=210  and distancia <=218: #71//////
        pasoV=b'p'
    if distancia >=219  and distancia <=225: #72
        pasoV=b'q'
    if distancia >=226  and distancia <=234:  #73
        pasoV=b'r'
    if distancia >=235  and distancia <=241:  #74
        pasoV=b's'
    if distancia >=242  and distancia <=250:  #75
        pasoV=b't'
    if distancia >=251  and distancia <=258:  #76
        pasoV=b'u'
    if distancia >=259  and distancia <=267:  #77
        pasoV=b'v'
    if distancia >=268  and distancia <=275:  #78
        pasoV=b'w'
    if distancia >=276  and distancia <=283:  #79
        pasoV=b'x'
    if distancia >=284  and distancia <=291:  #80
        pasoV=b'y'
    if distancia >=292  and distancia <=300:  #81
        pasoV=b'z'
    if distancia >=301  and distancia <=307:  #82
        pasoV=b'{'
    if distancia >=308  and distancia <=317:  #83
        pasoV=b'|'
    if distancia >=318  and distancia <=324:  #84
        pasoV=b'}'
    if distancia >=325  and distancia <=334:  #85
        pasoV=b'~'
    if distancia >=341:  #86
        pasoV=b' '
    return pasoV

# %% [markdown]
# realizar deteccion

# %%
import serial, time
arduino=serial.Serial('COM4',115200)
time.sleep(3)
cap = cv2.VideoCapture(0) # crear el objeto cap del tipo captura de video el cual va a tomar la camara wep en la pocicion 0 1
#dato=serial.Serial(port='COM3',baudrate=115200)#establecer comunicacion serial
a=1
while cap.isOpened(): # miestras la camara este abierta va a recorrer cada fotograma
    
    ret, frame = cap.read()#leer la camara y separar el frame y el ret
    
    # remodelar la imagen, el modelo movenet espera un input con el tamaño 192x192x3 de tipo float32
    
    img = frame.copy()
    img = tf.image.resize_with_pad(np.expand_dims(img, axis=0), 192,192)
    input_image = tf.cast(img, dtype=tf.float32)
    
    #configurar entradas y salidas
    
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    #realizar predicciones 
    interpreter.set_tensor(input_details[0]['index'], np.array(input_image)) # establecer detalles de entrada iguales a los de la salida
    interpreter.invoke() # invocar la prediccion
    keypoints_with_scores = interpreter.get_tensor(output_details[0]['index']) # obtener detalles de salida
    # matriz con los datos de pocion de cada punto de referencia
    #keypoints_with_scores =[nariz,ojo izquierdo, ojo derecho,oreja isquierda,oreja derecha,hombro izquierdo, hombro derecho, codo izquierdo,codo derecho, muñeca izquierda,muñecaderecha,
    # cadera izquierda, cadera derecha, rodilla izquierda, rodilla derecha,tobillo izquierdo,tobillo derecho]
    
    #OBTENER PUNTOS 
    nariz=keypoints_with_scores[0][0][0] #ontener coordenadas de la nariz (% en matriz de 192x192x3)
    Nariz=(nariz[:2]*[480,640]).astype(int) #tomar los valores de las coordenadas X y Y,pasarlo a las dimenciones reales de la imagen [alto,ancho] como valor entero
    PY=Nariz[0] 
    PX=Nariz[1]
    PT=nariz[2]
    
    
    if PT>0.35:
        if a==1:
            cad=pasosH(PX)
            arduino.write(cad)
            a=0
        else:
            cad=pasosV(PY)
            arduino.write(cad)
            a=1

    
    #dibujar puntos
    draw_keypoints(frame, keypoints_with_scores, 0.4) 
    cv2.imshow('MoveNet Lightning', frame) #se muestra el frame 
    #cv2.imwrite("frame%d.jpg" % ret, frame)  # tomar captura del frame
    if cv2.waitKey(10) & 0xFF==ord('q'): # leer teclado y si se preciona la letra q se cerrara el bucle de lectura de la camara
        
        break
   
cap.release() # liberar la camara web
cv2.destroyAllWindows() # cerrar la ventana 
arduino.close()

# %%
cap = cv2.VideoCapture(1)

# %%
cap.release()
